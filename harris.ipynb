# %%
from PIL import Image
import matplotlib.pyplot as plt

from scipy.ndimage import gaussian_filter
import numpy as np

# %%
def compute_harris(im,sigma=3):
    imx = np.zeros(im.shape)
    gaussian_filter(im,(sigma,sigma),(0,1),imx)
    imy = np.zeros(im.shape)
    gaussian_filter(im,(sigma,sigma),(1,0),imy)

    Wxx = gaussian_filter(imx*imx,sigma)
    Wxy = gaussian_filter(imx*imy,sigma)
    Wyy = gaussian_filter(imy*imy, sigma)

    Wdet = Wxx*Wyy - Wxy**2
    Wtr = Wxx +Wyy

    return Wdet / Wtr

# %%
def get_harris_points(harrisim, min_dist=10,threshold=0.1):
    corner_threshold = harrisim.max() * threshold
    harrisim_t = (harrisim>corner_threshold) * 1


    coords = np.array(harrisim_t.nonzero()).T

    candidate_values = [harrisim[c[0],c[1]] for c in coords]


    index = np.argsort(candidate_values)

    allowed_locations = np.zeros(harrisim.shape)
    allowed_locations[min_dist:-min_dist,min_dist:-min_dist] = 1


    filtered_coords = []
    for i in index:
        if allowed_locations[coords[i,0],coords[i,1]] == 1:
            filtered_coords.append(coords[i])
            allowed_locations[(coords[i,0]-min_dist):(coords[i,0]+min_dist),
                    (coords[i,1]-min_dist):(coords[i,1]+min_dist)] = 0

    return filtered_coords

# %%
import matplotlib.pyplot as plt
def plot_harris_points(image,filtered_coords):
  """ Plots corners found in image. """

  plt.figure()
  plt.gray()
  plt.imshow(image)
  plt.plot([p[1] for p in filtered_coords],[p[0] for p in filtered_coords],'*')
  plt.axis('off')
  plt.show()

# %%
im = np.array(Image.open('work/test.jpg').convert('L'))
harrisim = compute_harris(im)
filtered_coords = get_harris_points(harrisim,6)
plot_harris_points(im, filtered_coords)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 im = np.array(Image.open('work/test.jpg').convert('L'))
#       2 harrisim = compute_harris(im)
# ----> 3 filtered_coords = get_harris_points(harrisim,6)
#       4 plot_harris_points(im, filtered_coords)
#
# Cell In[42], line 21, in get_harris_points(harrisim, min_dist, threshold)
#      19     if allowed_locations[coords[i,0],coords[i,1]] == 1:
#      20         filtered_coords.append(coords[i])
# ---> 21         allowed_locations[(coords[i,0]-np.min_dist):(coords[i,0]+np.min_dist),
#      22                 (coords[i,1]-np.min_dist):(coords[i,1]+np.min_dist)] = 0
#      24 return filtered_coords
#
# File /opt/conda/lib/python3.11/site-packages/numpy/__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'min_dist'
