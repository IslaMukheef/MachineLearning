# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('work/test.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
#                               (input array image = gray, max corners =25, quality level = 0.01, distance 10 pix)
corners = cv.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.intp(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv.circle(img,(x,y),3,255,-1)

# %%
plt.imshow(img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x719d2c88d410>, None)
